# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("telecom_churn.csv")

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
print(df.shape)
# Out:
# (3333, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df["Churn"]=df["Churn"].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include=['object','bool'])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df["Churn"].value_counts()
# Out:
# Churn
# 0    2850
# 1     483
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# 0    0.855086
# 1    0.144914
# Name: proportion, dtype: float64

# %%
df["State"].value_counts()
# Out:
# State
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: count, dtype: int64

# %%
df.sort_values(by='Account length',ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 817     UT             243        510                 No              No
# 1408    NM             232        408                 No              No
# 1751    WY             225        415                 No              No
# 1551    MI             225        415                 No              No
# 1886    ID             224        510                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 817                       0               95.5               92
# 1408                      0              165.6              104
# 1751                      0              182.7              142
# 1551                      0              165.4              106
# 1886                      0              111.4              133
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by=['Account length','Area code'],ascending=[False,True]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 817     UT             243        510                 No              No
# 1408    NM             232        408                 No              No
# 1551    MI             225        415                 No              No
# 1751    WY             225        415                 No              No
# 416     DE             224        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 817                       0               95.5               92
# 1408                      0              165.6              104
# 1551                      0              165.4              106
# 1751                      0              182.7              142
# 416                       0              171.5               99
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df["Churn"].mean()
# Out:
# 0.14491449144914492

# %%
df.apply(np.max,axis=0)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %%
d={'No':False,'Yes':True}
df.replace({'International plan':})
# Out:
#      State  Account length  Area code  International plan Voice mail plan  \
# 0       KS             128        415               False             Yes
# 1       OH             107        415               False             Yes
# 2       NJ             137        415               False              No
# 3       OH              84        408                True              No
# 4       OK              75        415                True              No
# ...    ...             ...        ...                 ...             ...
# 3328    AZ             192        415               False             Yes
# 3329    WV              68        415               False              No
# 3330    RI              28        510               False              No
# 3331    CT             184        510                True              No
# 3332    TN              74        415               False             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             NaN
# 1    OH             107        415                 No             NaN
# 2    NJ             137        415                 No             NaN
# 3    OH              84        408                Yes             NaN
# 4    OK              75        415                Yes             NaN
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
columns_to_show = ['Total day minutes', 'Total eve minutes', 'Total night minutes']

df.groupby(['International plan'])[columns_to_show].agg([np.mean, np.std, np.min, np.max,np.sum])
# Out:
#                    Total day minutes                                    \
#                                 mean        std  amin   amax       sum
# International plan
# No                        178.893887  54.141286   0.0  350.8  538470.6
# Yes                       187.986997  56.850451  12.5  346.8   60719.8
#
#                    Total eve minutes                                    \
#                                 mean        std  amin   amax       sum
# International plan
# No                        200.663090  50.474772   0.0  361.8  603995.9
# Yes                       203.936842  52.879435  60.8  363.7   65871.6
#
#                    Total night minutes
#                                   mean        std  amin   amax       sum
# International plan
# No                          201.350831  50.366837  23.2  395.0  606066.0
# Yes                         196.410217  52.333632  72.4  352.5   63440.5

# %%
pd.crosstab(df['Account length'],df['International plan'],normalize=True)
# Out:
# International plan      No     Yes
# Account length
# 1                   0.0024  0.0000
# 2                   0.0000  0.0003
# 3                   0.0012  0.0003
# 4                   0.0000  0.0003
# 5                   0.0003  0.0000
# ...                    ...     ...
# 221                 0.0003  0.0000
# 224                 0.0003  0.0003
# 225                 0.0006  0.0000
# 232                 0.0003  0.0000
# 243                 0.0003  0.0000
#
# [212 rows x 2 columns]

# %%
df_current=df

# %%
df=pd.read_csv("telecom_churn.csv")

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df_current.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             NaN
# 1    OH             107        415                 No             NaN
# 2    NJ             137        415                 No             NaN
# 3    OH              84        408                Yes             NaN
# 4    OK              75        415                Yes             NaN
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3333, step=1)

# %%
df.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\5sem\ML\2 практика\practica.ipynb Ячейка 26 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/5sem/ML/2%20%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0/practica.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> df.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3333, step=1)

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.sample()
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 786    SD              85        408                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 786                      0              209.8               82
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 786             35.67              194.5               94             16.53
#
#      Total night minutes  Total night calls  Total night charge  \
# 786                200.4                 85                9.02
#
#      Total intl minutes  Total intl calls  Total intl charge  \
# 786                11.3                 3               3.05
#
#      Customer service calls  Churn
# 786                       0  False
